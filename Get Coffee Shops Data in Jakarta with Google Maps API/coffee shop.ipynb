# %%
pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.6.0.tar.gz (31 kB)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\lingga pratama\anaconda3\envs\linggapratama28\lib\site-packages (from googlemaps) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lingga pratama\anaconda3\envs\linggapratama28\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lingga pratama\anaconda3\envs\linggapratama28\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lingga pratama\anaconda3\envs\linggapratama28\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lingga pratama\anaconda3\envs\linggapratama28\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2021.10.8)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.6.0-py3-none-any.whl size=38554 sha256=68f05751ba4bdc91220acf0f8d4f579474915338741529e34203ab9ea2517f12
#   Stored in directory: c:\users\lingga pratama\appdata\local\pip\cache\wheels\b6\23\aa\a130b53682531f8382dd06f2000001225bea7b56a99c516f87
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
import pandas as pd
from pprint import pprint
import time

# %%
def miles_to_meters(miles):
    try:
        return miles * 1_609.344
    except:
        return 0

# %%
print(15 * 1_609.344)
# Out:
# 24140.16

# %%
API_KEY = open('API_KEY.txt', 'r').read()
map_client = googlemaps.Client(API_KEY)

# %%
location = [-6.207344988444389, 106.84963169426909]
search_string = ['coffee', 'kedai', 'roaster', 'roastery', 'kopi', 'cafe']
distance = miles_to_meters(15)
business_list = []

response = map_client.places_nearby(
    location=location,
    keyword=search_string,
    name='coffee shop',
    radius=distance
)

# %%
business_list.extend(response.get('results'))
next_page_token = response.get('next_page_token')

# %%
while next_page_token:
    time.sleep(2)
    response = map_client.places_nearby(
        location=location,
        keyword=search_string,
        name='coffee shop',
        radius=distance,
        page_token=next_page_token
    )
    business_list.extend(response.get('results'))
    next_page_token = response.get('next_page_token')

# %%
df = pd.DataFrame(business_list)
df['url'] = 'https://www.google.com/maps/place/?q=place_id:' + df['place_id']
df.to_excel('coffee shop.xlsx', index=False)

# %%
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AeJbb3ewj0TSZe1hSEhKHfHS5-9tyx4eY_6FIfg7K3w0pD3Ptj7tW0UX9-We0BiY5k8AloNKQOJ7Mw9f9XRJ4TmhOlsr01CNh6PaYK1VNcXEGaBxa8igb0F9FDo6L4lhP_ZSKacWR7eT7njQavOQ9lb9AtIuMgDUPm1YvQ0RqLBRylAcAFrZE8I5f2C2FCtLtIWBKZOn3HvDA_8rjaHptIkLAlnMkXv6jEGqUTTC_y0a6jIvmFiZAZ317GM970DVl826GrMs3tGKZts0P7FmMo_w7hMzEIxV3SIqdTTdsp28wv8rs8HHbdlbQF-GFu4pxR5Yu1xAfZc8xoALHC_hWCnq6gEgE1lfTTpfsHOmpj8zJQC08t7nng4s6mc__FmcIdcYwpuusnEIKZI_QolXhW65zC2EwA8_8zIWu4GXjzqGD1iY472HOPpanXOEG-mtdk_CskRBm-t5',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2203648, 'lng': 106.8234745},
#     'viewport': {'northeast': {'lat': -6.219021870107277,
#       'lng': 106.8248845298927},
#      'southwest': {'lat': -6.221721529892721, 'lng': 106.8221848701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Fillmore Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1281,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103606315284234546807">Indra Kusuma</a>'],
#      'photo_reference': 'AeJbb3dn1YmTiuSLDhq2qbgOtn41M2Dl_RIbzExkmmyjxRY7CYBg4cV6AVyTVyjGU5jtaGwkgjqwi7T1Q_G0MyQfIFozrNuykTLtrMXAzvUAQxhUocbztiyZpwVz6_5ojEW_8vZ_QWK5Tjvetj1D9MyTgVg4Vv4JVVOwSlVzLGBKyQmsKFg',
#      'width': 1252}],
#    'place_id': 'ChIJ64NT0f7zaS4RD49mHAZXcBM',
#    'plus_code': {'compound_code': 'QRHF+V9 Karet Kuningan, South Jakarta City, Jakarta',
#     'global_code': '6P58QRHF+V9'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJ64NT0f7zaS4RD49mHAZXcBM',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1124,
#    'vicinity': 'Jl. H. Sidik No.7, RT.4/RW.6, Kuningan, Karet Kuningan, Kuningan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.1913104, 'lng': 106.8241862},
#     'viewport': {'northeast': {'lat': -6.189958970107278,
#       'lng': 106.8255987298927},
#      'southwest': {'lat': -6.192658629892722, 'lng': 106.8228990701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Opal Coffee and Roastery',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106643317573358571272">Rio Aji Purnomo</a>'],
#      'photo_reference': 'AeJbb3dGtDb38-NEAzwVKnITBoVT3BVyF9LTi-goxNI4akSEg-mb2pM5KNOwnyEFGb89mPgBEEiCeIg_ZIr4Pabk0gIkyfSQ8WY5hiNYE6CD4g9iSaZrD69BJq2VBMRCqnKn531I3i3iE2oYRiYFjHT1Dyau92vD4zwNK9y6cKFSoJwm1wnI',
#      'width': 3000}],
#    'place_id': 'ChIJWRihBST0aS4RpvHffTXhmlk',
#    'plus_code': {'compound_code': 'RR5F+FM Gondangdia, Central Jakarta City, Jakarta',
#     'global_code': '6P58RR5F+FM'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJWRihBST0aS4RpvHffTXhmlk',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 103,
#    'vicinity': 'Jl. Riau No.9, RT.9/RW.5, Gondangdia, Kota Jakarta Pusat'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.241391, 'lng': 106.8075954},
#     'viewport': {'northeast': {'lat': -6.240051420107279,
#       'lng': 106.8088992798927},
#      'southwest': {'lat': -6.242751079892723, 'lng': 106.8061996201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Bunna Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4192,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113263082981031019771">A Google User</a>'],
#      'photo_reference': 'AeJbb3eix6lxKNyvObaCCuIsqU6bPR7zjNpaADRvVbpN8CUpdYC0jgM-nDoHeckobOvZ1IooiZuqtAaOnkAxqLYov_fE1oYWiUa--MeAIKKfVFZ5zjToSzNQTGxcDd6oYmCO71-1A6wFcJhgOQTwbRd5foO9J6n0CsRlXipSHebHCmgz13D4',
#      'width': 2797}],
#    'place_id': 'ChIJCxeK-WLxaS4REH_uEmbjZmE',
#    'plus_code': {'compound_code': 'QR55+C2 Petogogan, South Jakarta City, Jakarta',
#     'global_code': '6P58QR55+C2'},
#    'rating': 4.7,
#    'reference': 'ChIJCxeK-WLxaS4REH_uEmbjZmE',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 270,
#    'vicinity': 'Jl. Prof. Joko Sutono SH No.1D, RT.15/RW.6, Petogogan, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2256983, 'lng': 106.806466},
#     'viewport': {'northeast': {'lat': -6.224414570107278,
#       'lng': 106.8077489298927},
#      'southwest': {'lat': -6.227114229892722, 'lng': 106.8050492701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Bukanagara Coffee & Roastery',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107964304282340931335">A Google User</a>'],
#      'photo_reference': 'AeJbb3ffmbwIrxpcBMi76XF6xjy2gErzCENImUy-ds8TcReljCdOOCle3IPHIQv-QLZkfykWADhx_bHjbSSTO1S7v_jzJyDw89CniyosiWDIIFBgUh75lCY9KynAN0mQnk1Ls1oACu4vtcTZNSzION5cAd2mtHHcehWS5xp-x_xo6VNno3k',
#      'width': 3264}],
#    'place_id': 'ChIJD1E3IJfxaS4R4BO-uJQclT0',
#    'plus_code': {'compound_code': 'QRF4+PH Senayan, South Jakarta City, Jakarta',
#     'global_code': '6P58QRF4+PH'},
#    'rating': 4.7,
#    'reference': 'ChIJD1E3IJfxaS4R4BO-uJQclT0',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 319,
#    'vicinity': 'Graha CIMB Niaga, Jl. Jenderal Sudirman, RT.5/RW.3, Senayan, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2378168, 'lng': 106.8112996},
#     'viewport': {'northeast': {'lat': -6.236471720107278,
#       'lng': 106.8125756298927},
#      'southwest': {'lat': -6.239171379892722, 'lng': 106.8098759701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'NITRO COFFEE',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115303826776243305384">Aditya Kurnia</a>'],
#      'photo_reference': 'AeJbb3cjDrLMpVJlfFQ2mgkstmOtnIgSo6bW3bAw-eR9ptHxGx3VyxylpNPs5iLyOWEWFIRkT5uKFJF9PATsZoJbPnHR_fqG39mmbnzJEkKoN-70g8spbSFZuXlhnKmNMxQ5uRSXguZasUdvEx1V4nT-9ru1lWddmAcy7BBUcNV-763HjnQK',
#      'width': 4032}],
#    'place_id': 'ChIJQWIw913xaS4RO1_DFNIgs6Q',
#    'plus_code': {'compound_code': 'QR66+VG West Rawa, South Jakarta City, Jakarta',
#     'global_code': '6P58QR66+VG'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJQWIw913xaS4RO1_DFNIgs6Q',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1012,
#    'vicinity': 'Jl. Ciranjang No.10, RT.1/RW.1, Rw. Bar., Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2372116, 'lng': 106.7900146},
#     'viewport': {'northeast': {'lat': -6.235881170107278,
#       'lng': 106.7913137798927},
#      'southwest': {'lat': -6.238580829892722, 'lng': 106.7886141201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'First Crack Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100361330871831988535">Ignatius Kurniawan Lim</a>'],
#      'photo_reference': 'AeJbb3dt2JVsDdezEcEkU4V00EMz3b4p_gQOJSn8ix0el1ezDHtSnH-9c3jKlEhGnKWo1AYC6i2YN5i8bF4x2wyh8kG0Sv4VkwpVLmMG5BATlTbf6P9E2krZHY2rwwpksY-XZDVGvWUYMmoLhQXno2--Bwraou47nzhITl-oeIzH9VI8HzpF',
#      'width': 4032}],
#    'place_id': 'ChIJn_F4bgfxaS4RYW1AeXyoffk',
#    'plus_code': {'compound_code': 'QQ7R+42 Gunung, South Jakarta City, Jakarta',
#     'global_code': '6P58QQ7R+42'},
#    'rating': 4.8,
#    'reference': 'ChIJn_F4bgfxaS4RYW1AeXyoffk',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1330,
#    'vicinity': 'Jl. Bumi No.10, RT.2/RW.3, Gunung, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.290338, 'lng': 106.8015438},
#     'viewport': {'northeast': {'lat': -6.288978420107279,
#       'lng': 106.8030026298927},
#      'southwest': {'lat': -6.291678079892723, 'lng': 106.8003029701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'commonroom coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113641345998415301685">commonroom</a>'],
#      'photo_reference': 'AeJbb3f_guaB_CfDrc5DZx0Fzx1aPEGs1wq2wMflkfAm4HUqOYxL8-ZPu225CM1KW6vfp9mUcPCZDHen2_SxT3UID5rdMFj5gLxh-UrcnDbswP2Bte_LmYUyMhYn2JMsYMc0otVPteY_xZTQzgyQy_e9ikJrCIPpNRmbOfnkF0-gnl5uuWhr',
#      'width': 1024}],
#    'place_id': 'ChIJSd9IkuXxaS4RqMdK3uuHP2A',
#    'plus_code': {'compound_code': 'PR52+VJ West Cilandak, South Jakarta City, Jakarta',
#     'global_code': '6P58PR52+VJ'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJSd9IkuXxaS4RqMdK3uuHP2A',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 222,
#    'vicinity': 'Jl. Cilandak Tengah Raya No.1, RW.1, Cilandak Bar., Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2188779, 'lng': 106.8369392},
#     'viewport': {'northeast': {'lat': -6.217581070107277,
#       'lng': 106.8382970798927},
#      'southwest': {'lat': -6.220280729892721, 'lng': 106.8355974201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Escalator Coffee House',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115471746164801245094">Rizky Zulfikar</a>'],
#      'photo_reference': 'AeJbb3fAK8lnnsusOkDvZyM2lkh287kY4gNMhicyoUYi4LPA-owMee-BqNlZicLuCHEwRXtvExT8NghfPyKnvfL5uQ5IsFU13ZFu4AbAQpQoGuIeiy0HS6NDUd7FEcY1bsxv93X746LDIb3vS00zJkHOnDlHCWFw-WdRM7VyK-VzQ6VpRdZ7',
#      'width': 3024}],
#    'place_id': 'ChIJVVVVwfXzaS4RK9FK_N2iJzo',
#    'plus_code': {'compound_code': 'QRJP+CQ Menteng Atas, South Jakarta City, Jakarta',
#     'global_code': '6P58QRJP+CQ'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJVVVVwfXzaS4RK9FK_N2iJzo',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 161,
#    'vicinity': 'Rasuna Office Park unit BO-01, Jl. Taman Rasuna Selatan Jl. Taman Rasuna Tim., RT.17/RW.1, Menteng Atas, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2086843, 'lng': 106.8224708},
#     'viewport': {'northeast': {'lat': -6.207330470107277,
#       'lng': 106.8237308798927},
#      'southwest': {'lat': -6.210030129892721, 'lng': 106.8210312201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'The Coffee Bean & Tea Leaf',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101633259039494602028">A Google User</a>'],
#      'photo_reference': 'AeJbb3dk8N0NeNPedcGh-QgMa0fK2w5jz7LBAyFVAjvkmJ1QoryZh9fhaovgicuIlBTjPd7DivdldnfYCu0cqSPaiA4mBFMtFmmbmQ7_Q1Ggl9YQAYt2iwBRpnSNNgQnwkVd1n-LtFjviHYzsA-vJSgo70Z_pxmGK18_mzu-FmyD5FmpGAHk',
#      'width': 1440}],
#    'place_id': 'ChIJg1QmQgP0aS4R1h3wdrn0ccU',
#    'plus_code': {'compound_code': 'QRRC+GX Kuningan, Karet Kuningan, South Jakarta City, Jakarta',
#     'global_code': '6P58QRRC+GX'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJg1QmQgP0aS4R1h3wdrn0ccU',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 16,
#    'vicinity': 'Jl. Jend Sudirman Kav. 76-78 Setiabudi Setiabudi Jakarta Selatan DKI Jakarta RT.3, RT.2/RW.3, Kuningan, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.164176899999999, 'lng': 106.8205675},
#     'viewport': {'northeast': {'lat': -6.162962320107277,
#       'lng': 106.8219445298927},
#      'southwest': {'lat': -6.165661979892721, 'lng': 106.8192448701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Bengawan Solo Coffee - HXC',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100540201715279913590">PauL W.</a>'],
#      'photo_reference': 'AeJbb3dZIAlFB5XIOQT8FpwsgbJS1yD4UzT86xksrbf6C5i8ccwaBswrCfjMj5jKZqUwaz_Ht0vM1EhGh30375u4CUSqtN7MTfj0ryTzZO4DU2TJhtKnOmF2s54VvAGMUrZuLFIM0sxyKu0PEiHhnbMvdFB-UlVD-mwL02U3aVCPlX1FPAzs',
#      'width': 1280}],
#    'place_id': 'ChIJp7CAUdj1aS4RarGmmFdR9Cc',
#    'plus_code': {'compound_code': 'RRPC+86 Kebon Kelapa, Central Jakarta City, Jakarta',
#     'global_code': '6P58RRPC+86'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJp7CAUdj1aS4RarGmmFdR9Cc',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 227,
#    'vicinity': 'Gedung Harmoni Exchange, Jl. Hayam Wuruk VI, RT.6/RW.2, Kb. Klp., Kota Jakarta Pusat'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.221701899999999, 'lng': 106.8329},
#     'viewport': {'northeast': {'lat': -6.220408270107277,
#       'lng': 106.8342620298927},
#      'southwest': {'lat': -6.223107929892721, 'lng': 106.8315623701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Super Cup Coffee Shop',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111754372928824692817">jack 74</a>'],
#      'photo_reference': 'AeJbb3f28qBiOlgSMPEvXkkf2u89Q5j2hXGAKom2Ps3A3hQkxY4lzZnh9vajUoVGuNWPQ5I9dS6_hK9U_yYBDig-Xz74G7Sbxb_pkoDdx_gt9iUdCOfUxSlQ8nxBsAcRW4UnPM80UOUtTTsmq9i98IJPQlM5ycLqFWewQHkAZ-PP-AkICJiY',
#      'width': 1536}],
#    'place_id': 'ChIJ-8eV1_bzaS4RGcv6l8kxBsE',
#    'plus_code': {'compound_code': 'QRHM+85 Karet Kuningan, South Jakarta City, Jakarta',
#     'global_code': '6P58QRHM+85'},
#    'rating': 4.4,
#    'reference': 'ChIJ-8eV1_bzaS4RGcv6l8kxBsE',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 239,
#    'vicinity': 'Jalan H R Rasuna Said Plaza Festival Lantai GF Kav C 22, RT.2/RW.5, Kuningan, Karet Kuningan, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.1548243, 'lng': 106.8176539},
#     'viewport': {'northeast': {'lat': -6.153470170107278,
#       'lng': 106.8190232798927},
#      'southwest': {'lat': -6.156169829892722, 'lng': 106.8163236201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Enigma Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110486598338595879869">Lixia Zhang</a>'],
#      'photo_reference': 'AeJbb3cmZ8jfd6bJegXxOLcIRdu0lgIABVHEQ5hhdhs2mmF5zb_MBhRtH-KLs8rxXxOmw2SdAyqcKLm06mPQNk8HGMMi3TSsHF7jsQ0QcUrjGcATc6JQUv_SdNcVqyjC3fe6BSgY2QWWONbgeVgkWpCAPT5OCDx2hGb3Yz9JQKzbEA7fSVbR',
#      'width': 2250}],
#    'place_id': 'ChIJZZBzgb73aS4RWJC5Tb9PMT8',
#    'plus_code': {'compound_code': 'RRW9+32 Krukut, West Jakarta City, Jakarta',
#     'global_code': '6P58RRW9+32'},
#    'rating': 5,
#    'reference': 'ChIJZZBzgb73aS4RWJC5Tb9PMT8',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Jl. Gajah Mada No.95, RT.12/RW.7, Krukut, Kota Jakarta Barat'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.3163931, 'lng': 106.8143374},
#     'viewport': {'northeast': {'lat': -6.314956320107278,
#       'lng': 106.8157239298927},
#      'southwest': {'lat': -6.317655979892722, 'lng': 106.8130242701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Ladang Coffee Pack',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2304,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109968540371603052982">Iso Eddy</a>'],
#      'photo_reference': 'AeJbb3dNoESXsXsfsoL-8DMyvelrp0cj0bE91jfe8VVqUXy2p-3O7EsmR5G5XKVd_nhnsH_T_RyFwwAZ3_x27l2P1n95jtIwYARgAcEC68Wbxg4Um_tewlRm5TiQ1UsCkipDeS7ecAl3wHSp7KtgvVW9UB56VRKaN94D0L0jBEk8koy3KQC1',
#      'width': 3441}],
#    'place_id': 'ChIJH41seDHvaS4Rfl1hUj-Q3kY',
#    'plus_code': {'compound_code': 'MRM7+FP Jagakarsa, South Jakarta City, Jakarta',
#     'global_code': '6P58MRM7+FP'},
#    'rating': 4.4,
#    'reference': 'ChIJH41seDHvaS4Rfl1hUj-Q3kY',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 840,
#    'vicinity': 'Jl. Paso No.168, RT.5/RW.6, Jagakarsa, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2052112, 'lng': 106.858264},
#     'viewport': {'northeast': {'lat': -6.203891620107278,
#       'lng': 106.8595391298927},
#      'southwest': {'lat': -6.206591279892722, 'lng': 106.8568394701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Candi Coffee and Eatery',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116018685797374336611">Aviana Hanna Anggararini</a>'],
#      'photo_reference': 'AeJbb3eGqBVnLtAYQRZGKJMmav-N_UlBEfE8z-efOoLpRS1r1qba-W_XF2IvK62m0gsYdLVRnL-hlkQkaQVWN0dYdfxZc2rKAeoWJ936FnQKT6LAFXzKFIbuXEpi88yHXdcrWRP0QkG3MaLpx-0taddCTvexp4r79Azv-V9Beel7Vw6q4ZQZ',
#      'width': 1080}],
#    'place_id': 'ChIJkRJv5uf1aS4RLmWCgcQy1bY',
#    'plus_code': {'compound_code': 'QVV5+W8 Palmeriam, East Jakarta City, Jakarta',
#     'global_code': '6P58QVV5+W8'},
#    'rating': 4.5,
#    'reference': 'ChIJkRJv5uf1aS4RLmWCgcQy1bY',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 60,
#    'vicinity': 'Jl. Matraman Raya No.89, RT.1/RW.5, Palmeriam, Kota Jakarta Timur'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.227891899999999, 'lng': 106.8001912},
#     'viewport': {'northeast': {'lat': -6.226539270107279,
#       'lng': 106.8015200298927},
#      'southwest': {'lat': -6.229238929892722, 'lng': 106.7988203701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Fore Coffee - Panin Sudirman',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 6016,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113388735622521683085">A Google User</a>'],
#      'photo_reference': 'AeJbb3eZ4D2x917l9LaHQTbHbhLgigQH73ehUFyZmhX7JmmFcPGLhgPWZSr8ODPJi11SQg5AyRBS7iA6bpxqOm4r02dH9TFygGvqNvbazFY8dqYdrg7S15gws5RdKJ6GWvC80tM_JIk8ndIUOeXSKrwLC3tmUWXJSIc_xanmdXGGmhzLuwtF',
#      'width': 4016}],
#    'place_id': 'ChIJpYczgjn1aS4RFgf9BhdACYo',
#    'plus_code': {'compound_code': 'QRC2+R3 Gelora, Central Jakarta City, Jakarta',
#     'global_code': '6P58QRC2+R3'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJpYczgjn1aS4RFgf9BhdACYo',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 112,
#    'vicinity': '1, Jl. Jenderal Sudirman No.1, RT.1/RW.3, Gelora, Kota Jakarta Pusat'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.151682, 'lng': 106.8856393},
#     'viewport': {'northeast': {'lat': -6.150341820107277,
#       'lng': 106.8869645798927},
#      'southwest': {'lat': -6.153041479892721, 'lng': 106.8842649201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'First Crack Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110866177426375766361">Oscar Christi</a>'],
#      'photo_reference': 'AeJbb3ePphoOuVuEGDwKSN_fZGxuETzeRMylm1EyFhzWGikRsu-23lKCE-jhomcZqTq8JnEnKFnRD_L7I6ek3vQ_8XeMDmH0VhzBP9UUp2cGNsmSSeHikV7BNxLbBS-_rdGVJedzUXeJUN373G0kCnr6o_vq-7PVOBho5khrz6wDtjLzdVSD',
#      'width': 3840}],
#    'place_id': 'ChIJDSItAGv1aS4RRV-P0Vj833M',
#    'plus_code': {'compound_code': 'RVXP+87 Sunter Jaya, North Jakarta City, Jakarta',
#     'global_code': '6P58RVXP+87'},
#    'price_level': 2,
#    'rating': 4.7,
#    'reference': 'ChIJDSItAGv1aS4RRV-P0Vj833M',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1826,
#    'vicinity': 'Altira Business Park B12-15, Jl. Sunter Jaya Tim. Jl. Yos Sudarso Kav 85 No.9, RT.9/RW.11, Sunter Jaya, Kota Jkt Utara'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.365066100000001, 'lng': 106.8144244},
#     'viewport': {'northeast': {'lat': -6.363630470107278,
#       'lng': 106.8157817798927},
#      'southwest': {'lat': -6.366330129892722, 'lng': 106.8130821201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Coffith Coffee & Kitchen',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106254375753714243792">Nuzulia MS</a>'],
#      'photo_reference': 'AeJbb3cc9_yPeTYJwLelYMQ4yQdTyJhKS7QRgdrW7bcSNNHvykWcgyG41sIX6IECPQQMmCLeeAaZoDXp3MPpUo6-XEh4R-w-t2pO8CFZc6nJRlXJSkcvCnXWSPhiC-lGVsUqss-EcKgVn5vcSO1pbV_MMpmc_5F9xMpd2OHvsUsFeAJziHg7',
#      'width': 4000}],
#    'place_id': 'ChIJfWVWLqrvaS4RrI3HAg56MYU',
#    'plus_code': {'compound_code': 'JRM7+XQ Kukusan, Depok City, West Java',
#     'global_code': '6P58JRM7+XQ'},
#    'rating': 4.7,
#    'reference': 'ChIJfWVWLqrvaS4RrI3HAg56MYU',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 269,
#    'vicinity': 'Jl. K.H.M. Usman No.99, RT.1/RW.6, Kukusan, Kota Depok'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.277368, 'lng': 106.7728448},
#     'viewport': {'northeast': {'lat': -6.276017070107278,
#       'lng': 106.7741900798927},
#      'southwest': {'lat': -6.278716729892722, 'lng': 106.7714904201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Louie Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1350,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117236476643229720186">Dian Iswari</a>'],
#      'photo_reference': 'AeJbb3fT7qMxnSAyX9ogfqFNp3Ydky3qwwA_WV3PNDvzW4YcNxJ9hUXbMxzDKUX7ULOcrB9QftAauezvUr7zekktn1t0cR-rxoms1obA3RiA1x7wWwC6JwA-nwIOwfNwWC3tCddxvShi_ZEbJyjvINj2NWf770OfyYPt1qjEg_39Yf-dlsgt',
#      'width': 1080}],
#    'place_id': 'ChIJo797-rTxaS4ROcEpGgZw1ds',
#    'plus_code': {'compound_code': 'PQFF+25 Pondok Pinang, South Jakarta City, Jakarta',
#     'global_code': '6P58PQFF+25'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJo797-rTxaS4ROcEpGgZw1ds',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 446,
#    'vicinity': 'Jl. Ciputat Raya No.5, RT.4/RW.7, Pd. Pinang, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2408253, 'lng': 106.8144372},
#     'viewport': {'northeast': {'lat': -6.239443870107277,
#       'lng': 106.8156633798927},
#      'southwest': {'lat': -6.242143529892721, 'lng': 106.8129637201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'DomaDona Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104315509035426432679">Fx Ardhi</a>'],
#      'photo_reference': 'AeJbb3f24fWTwFtp4wn-s6yIm-WjKb6VC3P-lBiGZuuBcv3UuPZE1hgTkcurCuxCf9zsdiirRugqWYFht3HEWDRvqDopuM-x-cRnz4o4nEwTsC9Fcg22F-cPd0RGOOCBi6VpXjH23XEp2XpcIfY3SrjD3KfXgPxOAqs3rGRkCvGEJ9T94Fdq',
#      'width': 4160}],
#    'place_id': 'ChIJN-Td82DxaS4RMPRvTOsQTG8',
#    'plus_code': {'compound_code': 'QR57+MQ Petogogan, South Jakarta City, Jakarta',
#     'global_code': '6P58QR57+MQ'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJN-Td82DxaS4RMPRvTOsQTG8',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 609,
#    'vicinity': 'Jl. Wijaya I No.9AB, RT.6/RW.4, Petogogan, Kota Jakarta Selatan'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.2290989, 'lng': 106.8231439},
#     'viewport': {'northeast': {'lat': -6.227661420107277,
#       'lng': 106.8244883798927},
#      'southwest': {'lat': -6.230361079892721, 'lng': 106.8217887201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Meanwhile Coffee',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 6500,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112558238022441751956">rony bilberry</a>'],
#      'photo_reference': 'AeJbb3dZiDDthx5dkVGR-Pbk-rfRINPktheDu1XihWKuLrfEjkBCv-7QDNYPOB_SL1zbhkiQglLXSu2jG7oQauoqy6chJh4oPFi1uprgPPxV1gmlDNB4M-Y44nZhoKWpoSgPWPVLJnxW7cEIV7bAM0O683tIeD_JcLouWlaoR4ol8oLZJquH',
#      'width': 6500}],
#    'place_id': 'ChIJB9gfZ-PzaS4RezqhWOsLEJ0',
#    'plus_code': {'compound_code': 'QRCF+97 East Kuningan, South Jakarta City, Jakarta',
#     'global_code': '6P58QRCF+97'},
#    'rating': 4.8,
#    'reference': 'ChIJB9gfZ-PzaS4RezqhWOsLEJ0',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 159,
#    'vicinity': 'Kuningan Guest House, Jl. Perintis Jl. Mega Kuningan Barat No.16, RW.5, Kuningan, Kuningan Tim., Jakarta'}],
#  'status': 'OK'}

# %%
response.keys()
# Out:
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])
